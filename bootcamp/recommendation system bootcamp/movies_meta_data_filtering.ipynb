# %%
import pandas as pd

# %%
df = pd.read_csv('meta-data-movies.csv')
df.head(20)
# Out:
#                              title                                genres  \
# 0                        Toy Story     ['animation', 'comedy', 'family']
# 1                          Jumanji    ['adventure', 'fantasy', 'family']
# 2                 Grumpier Old Men                 ['romance', 'comedy']
# 3                Waiting to Exhale        ['comedy', 'drama', 'romance']
# 4      Father of the Bride Part II                            ['comedy']
# 5                             Heat          ['action', 'crime', 'drama']
# 6                          Sabrina                 ['comedy', 'romance']
# 7                     Tom and Huck      ['action', 'adventure', 'drama']
# 8                     Sudden Death   ['action', 'adventure', 'thriller']
# 9                        GoldenEye   ['adventure', 'action', 'thriller']
# 10          The American President        ['comedy', 'drama', 'romance']
# 11     Dracula: Dead and Loving It                  ['comedy', 'horror']
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22136 entries, 0 to 22135
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         22135 non-null  object
#  1   genres        22136 non-null  object
#  2   runtime       22100 non-null  float64
#  3   vote_average  22135 non-null  float64
#  4   vote_count    22135 non-null  float64
#  5   year          22136 non-null  int64
#  6   overview      21970 non-null  object
#  7   id            22136 non-null  int64
#  8   cast          22136 non-null  object
#  9   crew          22136 non-null  object
#  10  keywords      22136 non-null  object
#  11  director      21904 non-null  object
#  12  soup          22136 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 2.2+ MB

# %%
df.isna().sum()
# Out:
# title             1
# genres            0
# runtime          36
# vote_average      1
# vote_count        1
# year              0
# overview        166
# id                0
# cast              0
# crew              0
# keywords          0
# director        232
# soup              0
# dtype: int64

# %%
df[df['director'].isna()]
# Out:
#                                          title  \
# 189                                   The Show
# 614                            A Modern Affair
# 635                              Happy Weekend
# 661                                 Tarantella
# 718       War Stories Our Mother Never Told Us
# ...                                        ...
# 21815                            Bare Knuckles
# 21845                         Dance of Outlaws
# 21913           Resurrecting the Street Walker
# 21934  Year Zero: The Silent Death of Cambodia
# 22082                               Disfigured
#
#                                  genres  runtime  vote_average  vote_count  \
# 189                     ['documentary']     93.0           5.3         2.0
# 614                                  []     90.0           5.0         1.0
# 635                          ['comedy']      NaN           0.0         0.0
# 661                                  []    100.0           0.0         0.0
# ...
