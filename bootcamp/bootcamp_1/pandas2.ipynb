# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df = pd.read_csv('HappyCars.csv')
df.head(10)
# Out:
#    CustomerID  FirstName MiddleName LastName            BirthDate  \
# 0       11004  Elizabeth        NaN  Johnson  1968-08-08 00:00:00
# 1       11006      Janet          G  Alvarez  1965-12-06 00:00:00
# 2       11007      Marco        NaN    Mehta  1964-05-09 00:00:00
# 3       11008        Rob        NaN  Verhoff  1964-07-07 00:00:00
# 4       11009    Shannon          C  Carlson  1964-04-01 00:00:00
# 5       11011     Curtis        NaN       Lu  1963-11-04 00:00:00
# 6       11012     Lauren          M   Walker  1968-01-18 00:00:00
# 7       11013        Ian          M  Jenkins  1968-08-06 00:00:00
# 8       11014     Sydney        NaN  Bennett  1968-05-09 00:00:00
# 9       11015      Chloe        NaN    Young  1979-02-27 00:00:00
#
#   MaritalStatus  YearlyIncome Gender  TotalChildren  NumberChildrenAtHome  \
# 0             S  75001-100000      F            5.0                     5
# 1             S   50001-75000      F            0.0                     0
# ...

# %%
#Question1
df.shape
# Out:
# (10000, 16)

# %%
#Question2
df.dtypes
# Out:
# CustomerID                int64
# FirstName                object
# MiddleName               object
# LastName                 object
# BirthDate                object
# MaritalStatus            object
# YearlyIncome             object
# Gender                   object
# TotalChildren           float64
# NumberChildrenAtHome      int64
# Education                object
# Occupation               object
# HomeOwner                  bool
# CommuteDistance          object
# NumberOfPurchases         int64
# ProfitGenerated         float64
# dtype: object

# %%
#Question3
df.isna().sum()
# Out:
# CustomerID                 0
# FirstName                  0
# MiddleName              4270
# LastName                   0
# BirthDate                  0
# MaritalStatus              0
# YearlyIncome               0
# Gender                     0
# TotalChildren              8
# NumberChildrenAtHome       0
# Education                  0
# Occupation                 0
# HomeOwner                  0
# CommuteDistance            0
# NumberOfPurchases          0
# ProfitGenerated            0
# dtype: int64

# %%
#Question4
df.describe().loc[['mean','50%']]
# Out:
#       CustomerID  TotalChildren  NumberChildrenAtHome  NumberOfPurchases  \
# mean  20325.4693       2.071958                1.0813             2.2513
# 50%   20367.0000       2.000000                0.0000             2.0000
#
#       ProfitGenerated
# mean     12510.868637
# 50%      10622.392900

# %%
df.mode()
# Out:
#       CustomerID FirstName MiddleName LastName            BirthDate  \
# 0          11004     Devin          A     Diaz  1964-07-14 00:00:00
# 1          11006       NaN        NaN      NaN  1965-08-27 00:00:00
# 2          11007       NaN        NaN      NaN                  NaN
# 3          11008       NaN        NaN      NaN                  NaN
# 4          11009       NaN        NaN      NaN                  NaN
# ...          ...       ...        ...      ...                  ...
# 9995       29459       NaN        NaN      NaN                  NaN
# 9996       29460       NaN        NaN      NaN                  NaN
# 9997       29470       NaN        NaN      NaN                  NaN
# 9998       29472       NaN        NaN      NaN                  NaN
# 9999       29474       NaN        NaN      NaN                  NaN
#
#      MaritalStatus YearlyIncome Gender  TotalChildren  NumberChildrenAtHome  \
# ...

# %%
#Question5
df.nunique()
# Out:
# CustomerID              10000
# FirstName                 628
# MiddleName                 37
# LastName                  317
# BirthDate                6105
# MaritalStatus               2
# YearlyIncome                5
# Gender                      2
# TotalChildren               6
# NumberChildrenAtHome        7
# Education                   5
# Occupation                  5
# HomeOwner                   2
# CommuteDistance             5
# NumberOfPurchases           7
# ProfitGenerated          9999
# dtype: int64

# %%
df.describe(include='object').loc['unique']
# Out:
# FirstName           628
# MiddleName           37
# LastName            317
# BirthDate          6105
# MaritalStatus         2
# YearlyIncome          5
# Gender                2
# Education             5
# Occupation            5
# CommuteDistance       5
# Name: unique, dtype: object

# %%
#Question6

# %%
numeric_df = df.select_dtypes(include=np.number)
numeric_df.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'CustomerID'}>,
#         <AxesSubplot: title={'center': 'TotalChildren'}>],
#        [<AxesSubplot: title={'center': 'NumberChildrenAtHome'}>,
#         <AxesSubplot: title={'center': 'NumberOfPurchases'}>],
#        [<AxesSubplot: title={'center': 'ProfitGenerated'}>,
#         <AxesSubplot: >]], dtype=object)

# %%
#Question7

# %%
df.boxplot()
# Out:
# <AxesSubplot: >

# %%
df.corr()
# Out:
# /tmp/ipykernel_24773/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                       CustomerID  TotalChildren  NumberChildrenAtHome  \
# CustomerID              1.000000      -0.002717             -0.033829
# TotalChildren          -0.002717       1.000000              0.584350
# NumberChildrenAtHome   -0.033829       0.584350              1.000000
# HomeOwner              -0.102481       0.215814              0.181964
# NumberOfPurchases      -0.023607       0.267432              0.393011
# ProfitGenerated        -0.061831      -0.147321              0.007766
#
#                       HomeOwner  NumberOfPurchases  ProfitGenerated
# CustomerID            -0.102481          -0.023607        -0.061831
# TotalChildren          0.215814           0.267432        -0.147321
# ...

# %%
#Question9

# %%
df['BirthDate'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 df['BirthDate'].plot()
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/.local/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:450, in MPLPlot.generate(self)
#     448 def generate(self) -> None:
# ...
