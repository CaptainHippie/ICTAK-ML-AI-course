# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('train_v9rqX0R.csv')
df_train.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
df_sol = pd.read_csv('sample_submission_8RXa3c6.csv')
df_sol.head(10)
# Out:
#   Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0           FDW58            OUT049               1000
# 1           FDW14            OUT017               1000
# 2           NCN55            OUT010               1000
# 3           FDQ58            OUT017               1000
# 4           FDY38            OUT027               1000
# 5           FDH56            OUT046               1000
# 6           FDL48            OUT018               1000
# 7           FDC48            OUT027               1000
# 8           FDN33            OUT045               1000
# 9           FDA36            OUT017               1000

# %%
df_test = pd.read_csv('test_AbJTz2l.csv')
df_test.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDW58       20.750          Low Fat         0.007565
# 1           FDW14        8.300              reg         0.038428
# 2           NCN55       14.600          Low Fat         0.099575
# 3           FDQ58        7.315          Low Fat         0.015388
# 4           FDY38          NaN          Regular         0.118599
# 5           FDH56        9.800          Regular         0.063817
# 6           FDL48       19.350          Regular         0.082602
# 7           FDC48          NaN          Low Fat         0.015782
# 8           FDN33        6.305          Regular         0.123365
# 9           FDA36        5.985          Low Fat         0.005698
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_train.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
df_train['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
df_train['Item_Fat_Content'].isna().any()
# Out:
# False

# %%
df_train['Item_Fat_Content'] = ((df_train['Item_Fat_Content']=='Regular') | (df_train['Item_Fat_Content']=='reg')).astype(int)

# %%
df_train['Item_Fat_Content'].value_counts()
# Out:
# 0    5517
# 1    3006
# Name: Item_Fat_Content, dtype: int64

# %%
df_train.isna().any()
# Out:
# Item_Identifier              False
# Item_Weight                   True
# Item_Fat_Content             False
# Item_Visibility              False
# Item_Type                    False
# Item_MRP                     False
# Outlet_Identifier            False
# Outlet_Establishment_Year    False
# Outlet_Size                   True
# Outlet_Location_Type         False
# Outlet_Type                  False
# Item_Outlet_Sales            False
# dtype: bool

# %%
df_train['Item_Weight'].isna().sum()
# Out:
# 1463

# %%
df_train['Item_Weight'].hist()
# Out:
# <AxesSubplot: >

# %%
df_train['Outlet_Size'].isna().sum()
# Out:
# 2410

# %%
df_train['Outlet_Size'].hist()
# Out:
# <AxesSubplot: >

# %%
df_train['Outlet_Size_num'] = df_train['Outlet_Size'].replace(['Small', 'Medium','High'],[0,1,2])

# %%
df_train['Outlet_Size_num'].value_counts()
# Out:
# 1.0    2793
# 0.0    2388
# 2.0     932
# Name: Outlet_Size_num, dtype: int64

# %%
# fill missing values

# %%
df_train['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
df_train['Outlet_Location_Type_num'] = df_train['Outlet_Location_Type'].replace(['Tier 1', 'Tier 2','Tier 3'],[1,2,3])

# %%
df_train['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
df_train['Grocery Store'] = (df_train['Outlet_Type']=='Grocery Store').astype(int)

# %%
df_train['Supermarket'] = np.where(df_train['Outlet_Type'] == 'Grocery Store', 0, df_train['Outlet_Type'])
df_train['Supermarket'] = np.where(df_train['Outlet_Type'] == 'Supermarket Type1', 1, df_train['Supermarket'])
df_train['Supermarket'] = np.where(df_train['Outlet_Type'] == 'Supermarket Type2', 2, df_train['Supermarket'])
df_train['Supermarket'] = np.where(df_train['Outlet_Type'] == 'Supermarket Type3', 3, df_train['Supermarket'])

# %%
df_train[df_train['Outlet_Size'].isna()]
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200                 1         0.000000
# 8              FDH17       16.200                 1         0.016687
# 9              FDU28       19.200                 1         0.094450
# 25             NCD06       13.000                 0         0.099887
# 28             FDE51        5.925                 1         0.161467
# ...              ...          ...               ...              ...
# 8502           NCH43        8.420                 0         0.070712
# 8508           FDW31       11.350                 1         0.043246
# 8509           FDG45        8.100                 0         0.214306
# 8514           FDA01       15.000                 1         0.054489
# 8519           FDS36        8.380                 1         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %% [markdown]
# Assuming grocery would have lowest outlet size compared to Supermarket, it should get classified to Small.
# Also assuming higher tier supermarkets would have bigger size and higher tier location_type would have smaller size due to being expensive.
# So making a new column for outlet size score based on grocery/supermarket tier and location_type

# %%
df_train['Outlet_Score'] = (df_train['Supermarket'] ** 2)/ df_train['Outlet_Location_Type_num']

# %%
df_train['Outlet_Score'].value_counts()
# Out:
# 0.500000    2785
# 1.000000    1860
# 0.000000    1083
# 3.000000     935
# 0.333333     932
# 1.333333     928
# Name: Outlet_Score, dtype: int64

# %%
df_train[((df_train['Outlet_Score'] <= 1.5) & (df_train['Outlet_Size'] == 'Small'))]
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 11             FDA03        18.50                 1         0.045464
# 13             FDS46        17.60                 1         0.047257
# 15             FDP49         9.00                 1         0.069089
# 19             FDU02        13.35                 0         0.102492
# 22             NCB30        14.60                 0         0.025698
# ...              ...          ...               ...              ...
# 8510           FDN58        13.80                 1         0.056862
# 8513           FDH31        12.00                 1         0.020407
# 8517           FDF53        20.75                 1         0.083607
# 8520           NCJ29        10.60                 0         0.035186
# 8522           DRG01        14.80                 0         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 11                 Dairy  144.1102            OUT046
# ...

# %%
(df_train['Outlet_Score'] >= 1.5).sum()
# Out:
# 935

# %% [markdown]
# ## some wild theory

# %%
df_wp = df_train.iloc[:, 1:6]
df_wp.head(20)
# Out:
#     Item_Weight  Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.300                 0         0.016047                  Dairy
# 1         5.920                 1         0.019278            Soft Drinks
# 2        17.500                 0         0.016760                   Meat
# 3        19.200                 1         0.000000  Fruits and Vegetables
# 4         8.930                 0         0.000000              Household
# 5        10.395                 1         0.000000           Baking Goods
# 6        13.650                 1         0.012741            Snack Foods
# 7           NaN                 0         0.127470            Snack Foods
# 8        16.200                 1         0.016687           Frozen Foods
# 9        19.200                 1         0.094450           Frozen Foods
# 10       11.800                 0         0.000000  Fruits and Vegetables
# 11       18.500                 1         0.045464                  Dairy
# ...

# %%
df_train['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
df_wp_set = df_wp['Item_Weight'].notna()

# %%
# Out:
# 7060

# %%
itm_weigh = df_wp['Item_Weight']
type(itm_weigh)
# Out:
# pandas.core.series.Series

# %%
itm_weigh.head(20)
# Out:
# 0      9.300
# 1      5.920
# 2     17.500
# 3     19.200
# 4      8.930
# 5     10.395
# 6     13.650
# 7        NaN
# 8     16.200
# 9     19.200
# 10    11.800
# 11    18.500
# 12    15.100
# 13    17.600
# 14    16.350
# 15     9.000
# 16    11.800
# 17     9.000
# 18       NaN
# 19    13.350
# Name: Item_Weight, dtype: float64
